# %%
# ==============================
# 1. IMPORTS
# ==============================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# configuração visual
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10,6)

# ==============================
# 2. LOAD DATA
# ==============================

df = pd.read_csv("/home/avelaralencar/Desktop/zettaLab/data_focos_incendio/combined_focos_incendio.csv")

# ==============================
# 3. BASIC OVERVIEW
# ==============================

print("Shape:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nFirst rows:")
print(df.head())

print("\nLast rows:")
print(df.tail())

# ==============================
# 4. MISSING VALUES
# ==============================

missing = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

missing_df = pd.DataFrame({
    "Missing Values": missing,
    "Percent": missing_percent
}).sort_values(by="Percent", ascending=False)

print("\nMissing Values:")
print(missing_df)

# ==============================
# 5. DUPLICATES
# ==============================

duplicates = df.duplicated().sum()
print(f"\nDuplicated rows: {duplicates}")
# Out:
# Shape: (5244366, 9)
#
# Columns:
# Index(['id_bdq', 'foco_id', 'lat', 'lon', 'data_pas', 'pais', 'estado',
#        'municipio', 'bioma'],
#       dtype='str')
#
# Data Types:
# id_bdq         int64
# foco_id          str
# lat          float64
# lon          float64
# data_pas         str
# pais             str
# estado           str
# municipio        str
# bioma            str
# dtype: object
#
# First rows:
#      id_bdq                               foco_id     lat     lon  \
# 0  40756604  56344939-5abb-11e8-911c-28924ad12c5c -10.965 -39.248
# 1  40628131  56329e4b-5abb-11e8-911c-28924ad12c5c -12.597 -39.917
# 2  40484560  562fe0e9-5abb-11e8-911c-28924ad12c5c -13.805 -44.892
# 3  40134917  2b4544d3-5abb-11e8-911c-28924ad12c5c -20.311 -48.856
# 4  39718206  2b32eb5f-5abb-11e8-911c-28924ad12c5c -19.065 -44.692
#
#               data_pas    pais        estado  municipio     bioma
# 0  2007-11-09 15:36:00  Brasil         BAHIA  CANSANÇÃO  Caatinga
# 1  2007-11-01 16:25:00  Brasil         BAHIA       IAÇU  Caatinga
# 2  2007-10-25 16:19:00  Brasil         BAHIA  JABORANDI   Cerrado
# 3  2007-10-08 17:13:00  Brasil     SÃO PAULO   COLÔMBIA   Cerrado
# 4  2007-09-26 16:49:00  Brasil  MINAS GERAIS     POMPÉU   Cerrado
#
# Last rows:
#            id_bdq                               foco_id     lat     lon  \
# 5244361  46870242  5ba903e1-5abb-11e8-911c-28924ad12c5c -11.088 -43.259
# 5244362  47179527  5bb0d917-5abb-11e8-911c-28924ad12c5c  -6.923 -41.557
# 5244363  47268316  5bb27d3c-5abb-11e8-911c-28924ad12c5c  -3.123 -40.842
# 5244364  47355463  5bb4a7a1-5abb-11e8-911c-28924ad12c5c  -7.042 -38.734
# 5244365  47415722  5bb5b75c-5abb-11e8-911c-28924ad12c5c  -6.033 -38.324
#
#                     data_pas    pais estado municipio     bioma
# 5244361  2008-11-05 16:17:00  Brasil  BAHIA     BARRA   Cerrado
# 5244362  2008-11-25 15:54:00  Brasil  PIAUÍ     PICOS  Caatinga
# 5244363  2008-11-30 16:13:00  Brasil  CEARÁ    GRANJA  Caatinga
# 5244364  2008-12-06 15:36:00  Brasil  CEARÁ     BARRO  Caatinga
# 5244365  2008-12-10 16:49:00  Brasil  CEARÁ     ERERÊ  Caatinga
#
# Missing Values:
#            Missing Values   Percent
# bioma                   2  0.000038
# id_bdq                  0  0.000000
# foco_id                 0  0.000000
# lon                     0  0.000000
# lat                     0  0.000000
# data_pas                0  0.000000
# pais                    0  0.000000
# estado                  0  0.000000
# municipio               0  0.000000
#
# Duplicated rows: 0
